# %%
import numpy as np
from numpy import loadtxt

from pyESN import ESN
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def myMSE(prediction,target):
    return np.sqrt(np.mean((prediction.flatten() - target.flatten() )**2))

def residuals(prediction,target):
    return (target.flatten() - prediction.flatten())

def plotResults(trainlen, testlen, data, yfit, yhat, resTrain, resTest):
    plt.figure(figsize=(14,6))
    plt.subplot(2,1,1)
    plt.plot(range(0,trainlen+testlen), data,'k',  linewidth=2, label="data")
    plt.plot(range(0,trainlen),yfit,'--g',  linewidth=2, alpha=0.9, label="train")
    plt.plot(range(trainlen,trainlen+testlen), yhat,'--r', linewidth=2,  alpha=1, label="test")
    lo,hi = plt.ylim()
    plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'--b',alpha=0.8, linewidth=4)
    plt.tight_layout()
    plt.ylabel('y')
    plt.legend(loc=(0.61,1.1),fontsize='x-large')
    #
    plt.subplot(2,1,2)
    plt.plot(range(0,trainlen),resTrain,'--g',  linewidth=2, alpha=0.9, label="train")
    plt.plot(range(trainlen,trainlen+testlen), resTest,'--r', linewidth=2,  alpha=1, label="test")
    lo,hi = plt.ylim()
    plt.plot([trainlen,trainlen],[lo+np.spacing(1),hi-np.spacing(1)],'--b',alpha=0.8, linewidth=4)
    plt.tight_layout()
    plt.ylabel('Residuals')

# %% [markdown]
# ### Mackey Glass: Nonlinear function, solution of a delay nonlinear differential equation

# %%
data = np.load('data/mackey_glass_t17.npy') 
data = data[:3000]

trainlen = 2000
testlen  =1000
# Input  data
xtrain = np.ones(trainlen)
xtest=np.ones(testlen)
# Output data
ytrain = data[:trainlen]
ytest = data[trainlen:trainlen+testlen]

plt.figure(figsize=(14,2))
plt.plot(range(0,trainlen), ytrain,'r')
plt.plot(range(trainlen,trainlen+testlen), ytest,'-g')

# %%
# Setup the RC hyper-parameters
esn = ESN(n_inputs = 1,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius = 1.5,
          sparsity=.2,          
          random_state=42)

# Train and predict 
yfit = esn.fit(xtrain,ytrain)
yhat = prediction = esn.predict(xtest)

# %%
# MSE in the training and testing
scoreTrain = myMSE(yfit,ytrain)
scoreTest = myMSE(yhat,ytest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)

# Residuals 
resTrain = residuals(yfit,ytrain);
resTest = residuals(yhat,ytest);

# Plot:
plotResults(trainlen, testlen, data, yfit, yhat, resTrain, resTest)
# plt.savefig('MG_example.png', dpi = 300)
# Out:
# Training mean square error:  0.00011084861928947337
# Testing  mean square error:  0.09277461399234685

# %%
# Setup the RC hyper-parameters
esn = ESN(n_inputs = 1,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius = 1.5,
          sparsity=.2,
          out_activation = np.tanh,
          inverse_out_activation = np.arctanh,
          random_state=42)

    
# Train and predict 
yfit = esn.fit(xtrain,ytrain)
yhat = prediction = esn.predict(xtest)

# %%
# MSE in the training and testing
scoreTrain = myMSE(yfit,ytrain)
scoreTest = myMSE(yhat,ytest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)

# Residuals 
resTrain = residuals(yfit,ytrain);
resTest = residuals(yhat,ytest);

# Plot:
plotResults(trainlen, testlen, data, yfit, yhat, resTrain, resTest)
# Out:
# Training mean square error:  0.00013448752051684547
# Testing  mean square error:  0.03845208250442545

# %% [markdown]
# ### Rossler chaotic system

# %%
# lines = loadtxt("filename.dat", comments="#", delimiter=",", unpack=False)
tdata = loadtxt("data/t.dat")
xdata = loadtxt("data/x.dat")
ydata = loadtxt("data/y.dat")
zdata = loadtxt("data/z.dat")
N = len(tdata)
print("The time series consist of ", N, " points.")

plt.figure(figsize=(14,6))
plt.subplot(3,1,1)
plt.plot(tdata,xdata,'k')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.subplot(3,1,2)
plt.plot(tdata,ydata,'k')
plt.ylabel('y(t)')
plt.subplot(3,1,3)
plt.plot(tdata,zdata,'k')
plt.ylabel('z(t)');
plt.tight_layout()
# Out:
# The time series consist of  20000  points.

# %%
trainlen = 10000
testlen  = 10000

# Input  data
ttrain = np.ones(trainlen)
ttest=np.ones(testlen)

# ttrain = tdata[:trainlen]
# ttest  = tdata[trainlen:trainlen+testlen]

ytrain = ydata[:trainlen]
ztrain = zdata[:trainlen]
ytest  = ydata[trainlen:trainlen+testlen]
ztest  = zdata[trainlen:trainlen+testlen]

# Output data
xtrain = xdata[:trainlen]
xtest = xdata[trainlen:trainlen+testlen]


plt.figure(figsize=(14,2))
plt.plot(range(0,trainlen), xtrain,'r')
plt.plot(range(trainlen,trainlen+testlen), xtest,'-g')
# plt.plot(ttrain, xtrain,'b')
# plt.plot(ttest, xtest,'-r')

# %%
# Setup the RC hyper-parameters
esn = ESN(n_inputs = 1,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius = 1.5,
          sparsity=.2,
          noise = 0.002,
          random_state=42
         )


# esn = ESN(n_inputs = 1,
#           n_outputs = 1,
#           n_reservoir = 1000,
#           spectral_radius = 1.5,
#           sparsity=.2,
#           noise = 0.002,
#           out_activation = np.tanh,
#           inverse_out_activation = np.arctanh,
#           random_state=42
#          )



# Train and predict 
xfit = esn.fit(ttrain,xtrain)
xhat = prediction = esn.predict(ttest)

# %%
# MSE in the training and testing
scoreTrain = myMSE(xfit,xtrain)
scoreTest = myMSE(xhat,xtest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)
# Residuals 
resTrain = residuals(xfit,xtrain);
resTest = residuals(xhat,xtest);

# Plot:
plotResults(trainlen, testlen, xdata, xfit, xhat, resTrain, resTest)

# plt.savefig('xRossler.png', dpi = 300)
# Out:
# Training mean square error:  0.0002483340694736287
# Testing  mean square error:  1.3733560357994172

# %% [markdown]
# #### Observers

# %%
# inputTrain = np.stack((ttrain,ytrain), axis=1)
# inputTest = np.stack((ttest,ytest), axis=1)

# inputTrain = np.stack((ytrain,ztrain), axis=1)
# inputTest = np.stack((ytest,ztest), axis=1)

inputTrain = np.stack((ttrain,ytrain,ztrain), axis=1)
inputTest = np.stack((ttest,ytest,ztest), axis=1)

n_inp = len(inputTrain.T)
print(n_inp)
# Out:
# 3

# %%
esn = ESN(n_inputs = n_inp,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius =2, # 1.50, for short time prediction
          sparsity=.2,
          noise = 0.002,
          random_state=42
         )

# Train and predict 
xfit = esn.fit(inputTrain, xtrain)
xhat = prediction = esn.predict(inputTest)

# %%
# MSE in the training and testing
scoreTrain = myMSE(xfit,xtrain)
scoreTest = myMSE(xhat,xtest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)
# Residuals 
resTrain = residuals(xfit,xtrain);
resTest = residuals(xhat,xtest);

# Plot:
plotResults(trainlen, testlen, xdata, xfit, xhat, resTrain, resTest)

# plt.savefig('xRossler.png', dpi = 300)
# Out:
# Training mean square error:  0.026708485060908994
# Testing  mean square error:  0.3157441935904153

# %% [markdown]
# ### Lorentz

# %%
# lines = loadtxt("filename.dat", comments="#", delimiter=",", unpack=False)
xdata = loadtxt("data/LorenzModel/x.dat")
ydata = loadtxt("data/LorenzModel/y.dat")
zdata = loadtxt("data/LorenzModel/z.dat")

N = len(xdata)
print("The time series consist of ", N, " points.")

plt.figure(figsize=(14,6))
plt.subplot(3,1,1)
plt.plot(xdata,'k')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.subplot(3,1,2)
plt.plot(ydata,'k')
plt.ylabel('y(t)')
plt.subplot(3,1,3)
plt.plot(zdata,'k')
plt.ylabel('z(t)');
plt.tight_layout()
# Out:
# The time series consist of  2000  points.

# %% [markdown]
# #### Short range forecasting

# %%
tr_Perc = 0.95
trainlen = int(tr_Perc*N)
testlen  = N-trainlen
print(trainlen)

# Input  data
ttrain = np.ones(trainlen)
ttest=np.ones(testlen)

# Observers
ytrain = ydata[:trainlen]
ytest  = ydata[trainlen:trainlen+testlen]
xtrain = xdata[:trainlen]
xtest = xdata[trainlen:trainlen+testlen]

# Training/Target data
ztrain = zdata[:trainlen]
ztest  = zdata[trainlen:trainlen+testlen]




plt.figure(figsize=(14,2))
plt.plot(range(0,trainlen+testlen),zdata,'-k',label='data')
plt.plot(range(0,trainlen), ztrain,'r',label='Train')
plt.plot(range(trainlen,trainlen+testlen), ztest,'-g',label='Test')
# plt.legend(loc=(0.61,1.1),fontsize='x-large')
# Out:
# 1900

# %%
inputTrain = ttrain
inputTest = ttest
n_inp = 1 
print(n_inp)


esn = ESN(n_inputs = n_inp,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius = .95,
          sparsity=.19,
          noise = 0.0001,
          random_state=42,
          silent = True
         )

# Train and predict 
zfit = esn.fit(inputTrain, ztrain)
zhat = prediction = esn.predict(inputTest)
# Out:
# 1

# %%
# MSE in the training and testing
scoreTrain = myMSE(zfit,ztrain)
scoreTest = myMSE(zhat,ztest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)
# Residuals 
resTrain = residuals(zfit,ztrain)
resTest = residuals(zhat, ztest)

# Plot:
plotResults(trainlen, testlen, zdata, zfit, zhat, resTrain, resTest)

# plt.savefig('xLorenz.png', dpi = 300)
# Out:
# Training mean square error:  4.570514460960242e-05
# Testing  mean square error:  0.025255565728328325

# %% [markdown]
# #### Long Range forecasting: Inference

# %%
tr_Perc = 0.70
trainlen = int(tr_Perc*N)
testlen  = int((1-tr_Perc)*N)


# Input  data
ttrain = np.ones(trainlen)
ttest=np.ones(testlen)

# Observers
ytrain = ydata[:trainlen]
ytest  = ydata[trainlen:trainlen+testlen]
xtrain = xdata[:trainlen]
xtest = xdata[trainlen:trainlen+testlen]

# Training/Target data
ztrain = zdata[:trainlen]
ztest  = zdata[trainlen:trainlen+testlen]


plt.figure(figsize=(14,2))
plt.plot(range(0,trainlen), ztrain,'r',label='Train')
plt.plot(range(trainlen,trainlen+testlen), ztest,'-g',label='Test')
plt.legend(loc=(0.61,1.1),fontsize='x-large')

# %%
inputTrain = ttrain
inputTest = ttest
n_inp = 1 
print(n_inp)


esn = ESN(n_inputs = n_inp,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius = .95,
          sparsity=.19,
          noise = 0.0001,
          random_state=42,
          silent = True,
          input_scaling=1
         )

# Train and predict 
zfit = esn.fit(inputTrain, ztrain)
zhat = prediction = esn.predict(inputTest)
# Out:
# 1

# %%
# MSE in the training and testing
scoreTrain = myMSE(zfit,ztrain)
scoreTest = myMSE(zhat,ztest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)
# Residuals 
resTrain = residuals(zfit,ztrain);
resTest = residuals(zhat, ztest);

# Plot:
plotResults(trainlen, testlen, zdata, zfit, zhat, resTrain, resTest)

# plt.savefig('xLorenz.png', dpi = 300)
# Out:
# Training mean square error:  3.542456710809703e-05
# Testing  mean square error:  0.41393125952919285

# %%
inputTrain = np.stack((ttrain, xtrain, ytrain), axis=1)
inputTest = np.stack((ttest, xtest, ytest), axis=1)

n_inp = len(inputTrain.T)
print(n_inp)

esn = ESN(n_inputs = n_inp,
          n_outputs = 1,
          n_reservoir = 600,
          spectral_radius = 0.1,
          sparsity=.15,
          noise = 0.00053,
          random_state=42,
          silent = True
#           input_scaling=1
         )

# Train and predict 
zfit = esn.fit(inputTrain, ztrain)
zhat = prediction = esn.predict(inputTest)
# Out:
# 3

# %%
# MSE in the training and testing
scoreTrain = myMSE(zfit,ztrain)
scoreTest = myMSE(zhat,ztest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)
# Residuals 
resTrain = residuals(zfit,ztrain);
resTest = residuals(zhat, ztest);

# Plot:
plotResults(trainlen, testlen, zdata, zfit, zhat, resTrain, resTest)
# plt.savefig('xLorenz.png', dpi = 300)
# Out:
# Training mean square error:  0.00026157382999480934
# Testing  mean square error:  3.491644084688355

# %% [markdown]
# ### Henon-Heiles System

# %%
# lines = loadtxt("filename.dat", comments="#", delimiter=",", unpack=False)
tdata = loadtxt("data/HenonHeiles/t.dat")
xdata = loadtxt("data/HenonHeiles/x.dat")
ydata = loadtxt("data/HenonHeiles/y.dat")

N = len(tdata)
print("The time series consist of ", N, " points.")

plt.figure(figsize=(14,6))
plt.subplot(2,1,1)
plt.plot(tdata,xdata,'k')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.subplot(2,1,2)
plt.plot(tdata,ydata,'k')
plt.ylabel('y(t)')
plt.tight_layout()
# Out:
# The time series consist of  1000  points.

# %% [markdown]
# #### Short range forecast

# %%
trainlen = int(0.8*N)
testlen  = int(0.2*N)
trainlen = int(0.5*N)
testlen  = int(0.5*N)


# Input  data
ttrain = np.ones(trainlen)
ttest=np.ones(testlen)

# ttrain = tdata[:trainlen]
# ttest  = tdata[trainlen:trainlen+testlen]

ytrain = ydata[:trainlen]
ytest  = ydata[trainlen:trainlen+testlen]

# Output data
xtrain = xdata[:trainlen]
xtest = xdata[trainlen:trainlen+testlen]


plt.figure(figsize=(14,2))
plt.plot(range(0,trainlen), xtrain,'r')
plt.plot(range(trainlen,trainlen+testlen), xtest,'-g')
# plt.plot(ttrain, xtrain,'b')
# plt.plot(ttest, xtest,'-r')

# %%
inputTrain = ttrain
inputTest = ttest
# inputTrain = np.stack((ttrain), axis=1)
# inputTest = np.stack((ttest), axis=1)
# n_inp = len(inputTrain)
n_inp = 1 
print(n_inp)

esn = ESN(n_inputs = n_inp,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius = 1.5,
          sparsity=.2,
          noise = 0.002,
          random_state=42,
          silent = False
         )


# Train and predict 
xfit = esn.fit(inputTrain, xtrain)
xhat = prediction = esn.predict(inputTest)
# Out:
# 1
# harvesting states...
# fitting...
# training error:
# 8.532973675134317e-15

# %%
# MSE in the training and testing
scoreTrain = myMSE(xfit,xtrain)
scoreTest = myMSE(xhat,xtest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)
# Residuals 
resTrain = residuals(xfit,xtrain);
resTest = residuals(xhat,xtest);

# Plot:
plotResults(trainlen, testlen, xdata, xfit, xhat, resTrain, resTest)

# plt.savefig('xHH.png', dpi = 300)
# Out:
# Training mean square error:  8.532973675134317e-15
# Testing  mean square error:  0.09484324103191898

# %% [markdown]
# #### Long range forecast (inference)

# %%
trainlen = int(0.5*N)
testlen  = int(0.5*N)

# Input  data
ttrain = np.ones(trainlen)
ttest=np.ones(testlen)

ytrain = ydata[:trainlen]
ytest  = ydata[trainlen:trainlen+testlen]

# Output data
xtrain = xdata[:trainlen]
xtest = xdata[trainlen:trainlen+testlen]


plt.figure(figsize=(14,2))
plt.plot(range(0,trainlen), xtrain,'r')
plt.plot(range(trainlen,trainlen+testlen), xtest,'-g')
# plt.plot(ttrain, xtrain,'b')
# plt.plot(ttest, xtest,'-r')

# %%
inputTrain = np.stack((ttrain,ytrain), axis=1)
inputTest = np.stack((ttest,ytest), axis=1)

n_inp = len(inputTrain.T)
print(n_inp)

esn = ESN(n_inputs = n_inp,
          n_outputs = 1,
          n_reservoir = 1000,
          spectral_radius = 1.5,
          sparsity=.2,
          noise = 0.002,
          random_state=42
         )

# Train and predict 
xfit = esn.fit(inputTrain, xtrain)
xhat = prediction = esn.predict(inputTest)
# Out:
# 2

# %%
# MSE in the training and testing
scoreTrain = myMSE(xfit,xtrain)
scoreTest = myMSE(xhat,xtest)
print("Training mean square error: ",scoreTrain)
print("Testing  mean square error: ",scoreTest)
# Residuals 
resTrain = residuals(xfit,xtrain);
resTest = residuals(xhat,xtest);

# Plot:
plotResults(trainlen, testlen, xdata, xfit, xhat, resTrain, resTest)

# plt.savefig('xHH.png', dpi = 300)
# Out:
# Training mean square error:  3.440418401702706e-14
# Testing  mean square error:  0.001329703385646166

# %%
# lines = loadtxt("filename.dat", comments="#", delimiter=",", unpack=False)
tdata = loadtxt("data/HenonHeiles/t.dat")
xdata = loadtxt("data/HenonHeiles/x.dat")
ydata = loadtxt("data/HenonHeiles/y.dat")

N = len(tdata)
print("The time series consist of ", N, " points.")

plt.figure(figsize=(14,6))
plt.subplot(2,1,1)
plt.plot(tdata,xdata,'k')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.subplot(2,1,2)
plt.plot(tdata,ydata,'k')
plt.ylabel('y(t)')
plt.tight_layout()

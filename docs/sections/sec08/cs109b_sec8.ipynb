# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> Data Science 2: Advanced Topics in Data Science
# ## Section 8: Operationalizing Models
#
#
# **Harvard University**<br/>
# **Spring 2021**<br/>
# **Instructors**: Mark Glickman, Pavlos Protopapas, and Chris Tanner <br/>
# **Authors**: Shivas Jayaram
#
#
# <hr style="height:2pt">

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you should be able to:
# * Train an end to end image classification model
# * Understand various CNN model architecturea and see which one works the best
# * Save the best model so we can use it in our app

# %% [markdown]
# <a id="contents"></a>
#
# ## Notebook Contents
# - **Dataset**
#     - Download
#     - Load Data
#     - View Images
#     - Split Data
# - **Build Data Pipelines**
#     - Create TF Datasets
# - **Image Classification Models**
#     - Small CNN Network
#     - Medium CNN Network
#     - Large CNN Network
#     - MobileNet - Transfer Learning
#     - MobileNet - Transfer Learning (From TFHub)
# - **Compare all Models**
#     - Find Best Model
#     - Predict using best model

# %% [markdown]
# ## **Setup Notebook**

# %% [markdown]
# **Imports**

# %%
import os
import requests
import zipfile
import tarfile
import shutil
import math
import json
import time
import sys
import cv2
import string
import re
import numpy as np
import pandas as pd
from glob import glob
import collections
import unicodedata
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.utils.layer_utils import count_params

# Tensorflow Hub
import tensorflow_hub as hub

# sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Verify Setup**

# %%
# Enable/Disable Eager Execution
# Reference: https://www.tensorflow.org/guide/eager
# TensorFlow's eager execution is an imperative programming environment that evaluates operations immediately, 
# without building graphs

#tf.compat.v1.disable_eager_execution()
#tf.compat.v1.enable_eager_execution()

print("tensorflow version", tf.__version__)
print("keras version", tf.keras.__version__)
print("Eager Execution Enabled:", tf.executing_eagerly())

# Get the number of replicas 
strategy = tf.distribute.MirroredStrategy()
print("Number of replicas:", strategy.num_replicas_in_sync)

devices = tf.config.experimental.get_visible_devices()
print("Devices:", devices)
print(tf.config.experimental.list_logical_devices('GPU'))

print("GPU Available: ", tf.config.list_physical_devices('GPU'))
print("All Physical Devices", tf.config.list_physical_devices())

# Better performance with the tf.data API
# Reference: https://www.tensorflow.org/guide/data_performance
AUTOTUNE = tf.data.experimental.AUTOTUNE
# Out:
# tensorflow version 2.4.1
# keras version 2.4.0
# Eager Execution Enabled: True
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of replicas: 1
# Devices: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# GPU Available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# All Physical Devices [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# **Utils**
#
# Here we define some helper functions that would be used in loading data, saving models and evaluating models.

# %%
def download_file(packet_url, base_path="", extract=False, headers=None):
  if base_path != "":
    if not os.path.exists(base_path):
      os.mkdir(base_path)
  packet_file = os.path.basename(packet_url)
  with requests.get(packet_url, stream=True, headers=headers) as r:
      r.raise_for_status()
      with open(os.path.join(base_path,packet_file), 'wb') as f:
          for chunk in r.iter_content(chunk_size=8192):
              f.write(chunk)
  
  if extract:
    if packet_file.endswith(".zip"):
      with zipfile.ZipFile(os.path.join(base_path,packet_file)) as zfile:
        zfile.extractall(base_path)
    else:
      packet_name = packet_file.split('.')[0]
      with tarfile.open(os.path.join(base_path,packet_file)) as tfile:
        tfile.extractall(base_path)

class JsonEncoder(json.JSONEncoder):
  def default(self, obj):
    if isinstance(obj, np.integer):
        return int(obj)
    elif isinstance(obj, np.floating):
        return float(obj)
    elif isinstance(obj, decimal.Decimal):
        return float(obj)
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    else:
        return super(JsonEncoder, self).default(obj)

def save_model(model, path="models",model_name="model01"):

  # Ensure path exists
  if not os.path.exists(path):
      os.mkdir(path)

  # Save the enitire model (structure + weights)
  model.save(os.path.join(path,model_name+".hdf5"))

  # Save only the weights
  model.save_weights(os.path.join(path,model_name+".h5"))

  # Save the structure only
  model_json = model.to_json()
  with open(os.path.join(path,model_name+".json"), "w") as json_file:
      json_file.write(model_json)

def get_model_size(path="models",model_name="model01"):
  model_size = os.stat(os.path.join(path,model_name+".hdf5")).st_size
  return model_size

def evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True):
    
  # Get the model train history
  model_train_history = training_results.history
  # Get the number of epochs the training was run for
  num_epochs = len(model_train_history["loss"])

  # Plot training results
  fig = plt.figure(figsize=(15,5))
  axs = fig.add_subplot(1,2,1)
  axs.set_title('Loss')
  # Plot all metrics
  for metric in ["loss","val_loss"]:
      axs.plot(np.arange(0, num_epochs), model_train_history[metric], label=metric)
  axs.legend()
  
  axs = fig.add_subplot(1,2,2)
  axs.set_title('Accuracy')
  # Plot all metrics
  for metric in ["accuracy","val_accuracy"]:
      axs.plot(np.arange(0, num_epochs), model_train_history[metric], label=metric)
  axs.legend()

  plt.show()
  
  # Evaluate on test data
  evaluation_results = model.evaluate(test_data)
  print(evaluation_results)
  
  if save:
    # Save model
    save_model(model, model_name=model.name)
    model_size = get_model_size(model_name=model.name)

    # Save model history
    with open(os.path.join("models",model.name+"_train_history.json"), "w") as json_file:
        json_file.write(json.dumps(model_train_history,cls=JsonEncoder))

    trainable_parameters = count_params(model.trainable_weights)
    non_trainable_parameters = count_params(model.non_trainable_weights)

    # Save model metrics
    metrics ={
        "trainable_parameters":trainable_parameters,
        "execution_time":execution_time,
        "loss":evaluation_results[0],
        "accuracy":evaluation_results[1],
        "model_size":model_size,
        "learning_rate":learning_rate,
        "batch_size":batch_size,
        "epochs":epochs,
        "optimizer":type(optimizer).__name__
    }
    with open(os.path.join("models",model.name+"_model_metrics.json"), "w") as json_file:
        json_file.write(json.dumps(metrics,cls=JsonEncoder))

# %% [markdown]
# ## **Dataset**
#
# The dataset consists of images of mushrooms downloaded from Google Images. There are three types of mushrooms: 'oyster', 'crimini', 'amanita

# %% [markdown]
# ### **Download**
#
# Download the datasets to colab.

# %%
start_time = time.time()
download_file("https://storage.googleapis.com/cs109b/datasets/mushrooms.zip", base_path="datasets", extract=True)
execution_time = (time.time() - start_time)/60.0
print("Download execution time (mins)",execution_time)
# Out:
# Download execution time (mins) 0.21485764582951863

# %% [markdown]
# ### **Load Data**
#
# * Read-in data as lists.
# * Each element in data_x is the path to the image
# * Each element in data_y is the label of that image

# %%
base_path = os.path.join("datasets","mushrooms")
label_names = os.listdir(base_path)
print("Labels:", label_names)

# Number of unique labels
num_classes = len(label_names) 
# Create label index for easy lookup
label2index = dict((name, index) for index, name in enumerate(label_names))
index2label = dict((index, name) for index, name in enumerate(label_names))

# Generate a list of labels and path to images
data_list = []
for label in label_names:
  # Images
  image_files = os.listdir(os.path.join(base_path,label))
  data_list.extend([(label,os.path.join(base_path,label,f)) for f in image_files])

print("Full size of the dataset:",len(data_list))
print(data_list[:5])

# Build data x, y
data_x = [x[1] for x in data_list]
data_y = [x[0] for x in data_list]

print("data_x:",data_x[:5])
print("data_y:",data_y[:5])
# Out:
# Labels: ['crimini', 'amanita', 'oyster']
# Full size of the dataset: 1643
# [('crimini', 'datasets/mushrooms/crimini/232.jpg'), ('crimini', 'datasets/mushrooms/crimini/118.jpg'), ('crimini', 'datasets/mushrooms/crimini/415.jpg'), ('crimini', 'datasets/mushrooms/crimini/95.jpg'), ('crimini', 'datasets/mushrooms/crimini/370.jpg')]
# data_x: ['datasets/mushrooms/crimini/232.jpg', 'datasets/mushrooms/crimini/118.jpg', 'datasets/mushrooms/crimini/415.jpg', 'datasets/mushrooms/crimini/95.jpg', 'datasets/mushrooms/crimini/370.jpg']
# data_y: ['crimini', 'crimini', 'crimini', 'crimini', 'crimini']

# %% [markdown]
# ### **View Images**
#
# Let's take a look at the data.

# %%
# View some images

# Generate a random sample of index
image_samples = np.random.randint(0,high=len(data_list)-1, size=12)

fig = plt.figure(figsize=(20,8))
for i,img_idx in enumerate(image_samples):
    axs = fig.add_subplot(3,4,i+1)
    axs.set_title(data_list[img_idx][0])
    # Read image
    image = cv2.imread(data_list[img_idx][1])
    # convert to rgb
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)
    plt.axis('off')

plt.suptitle("Sample Images")
plt.show()

# %% [markdown]
# ### **Split Data**
# We split data into train, validation, and test by randomly selecting 10% as the test set and 20% as the validation set.

# %%
test_percent = 0.10
validation_percent = 0.2

# Split data into train / test
train_validate_x, test_x, train_validate_y, test_y = train_test_split(data_x, data_y, test_size=test_percent)

# Split data into train / validate
train_x, validate_x, train_y, validate_y = train_test_split(train_validate_x, train_validate_y, test_size=test_percent)

print("train_x count:",len(train_x))
print("validate_x count:",len(validate_x))
print("test_x count:",len(test_x))
# Out:
# train_x count: 1330
# validate_x count: 148
# test_x count: 165

# %% [markdown]
# ## **Build Data Pipelines**

# %% [markdown]
# ### **Create TF Datasets**

# %%
image_width = 224
image_height = 224
num_channels = 3
batch_size = 32
train_shuffle_buffer_size= len(train_x)
validation_shuffle_buffer_size= len(validate_x)

# Load Image
def load_image(path, label):
  image = tf.io.read_file(path)
  image = tf.image.decode_jpeg(image, channels=num_channels)
  image = tf.image.resize(image, [image_height,image_width])
  return image, label

# Normalize pixels
def normalize(image, label):
  image = image/255
  #image = keras.applications.mobilenet.preprocess_input(image)
  return image, label

# Convert all y labels to numbers
train_processed_y = [label2index[label] for label in train_y]
validate_processed_y = [label2index[label] for label in validate_y]
test_processed_y = [label2index[label] for label in test_y]

# Converts to y to binary class matrix (One-hot-encoded)
train_processed_y = to_categorical(train_processed_y, num_classes=num_classes, dtype='float32')
validate_processed_y = to_categorical(validate_processed_y, num_classes=num_classes, dtype='float32')
test_processed_y = to_categorical(test_processed_y, num_classes=num_classes, dtype='float32')

# Create TF Dataset
train_data = tf.data.Dataset.from_tensor_slices((train_x, train_processed_y))
validation_data = tf.data.Dataset.from_tensor_slices((validate_x, validate_processed_y))
test_data = tf.data.Dataset.from_tensor_slices((test_x, test_processed_y))

#############
# Train data
#############
# Apply all data processing logic
train_data = train_data.map(load_image, num_parallel_calls=AUTOTUNE)
train_data = train_data.map(normalize, num_parallel_calls=AUTOTUNE)
train_data = train_data.shuffle(buffer_size=train_shuffle_buffer_size)
train_data = train_data.batch(batch_size)

##################
# Validation data
##################
# Apply all data processing logic
validation_data = validation_data.map(load_image, num_parallel_calls=AUTOTUNE)
validation_data = validation_data.map(normalize, num_parallel_calls=AUTOTUNE)
validation_data = validation_data.shuffle(buffer_size=validation_shuffle_buffer_size)
validation_data = validation_data.batch(batch_size)

############
# Test data
############
# Apply all data processing logic
test_data = test_data.map(load_image, num_parallel_calls=AUTOTUNE)
test_data = test_data.map(normalize, num_parallel_calls=AUTOTUNE)
test_data = test_data.batch(batch_size)

print("train_data",train_data)
print("validation_data",validation_data)
print("test_data",test_data)
# Out:
# train_data <BatchDataset shapes: ((None, 224, 224, 3), (None, 3)), types: (tf.float32, tf.float32)>
# validation_data <BatchDataset shapes: ((None, 224, 224, 3), (None, 3)), types: (tf.float32, tf.float32)>
# test_data <BatchDataset shapes: ((None, 224, 224, 3), (None, 3)), types: (tf.float32, tf.float32)>

# %% [markdown]
# ## **Image Classificaton Models**

# %% [markdown]
# ### **Small CNN Network**

# %%
# Build Model
def build_small_model(image_height, image_width, num_channels, num_classes):
  # Model input
  input_shape = [image_height, image_width, num_channels] # height, width, channels
  model_input = keras.Input(shape=input_shape)

  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(model_input)
  hidden = keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)

  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)

  # Flatten
  hidden = keras.layers.Flatten()(hidden)

  #  Hidden Layer, Classification Block
  hidden = keras.layers.Dense(units=64, activation='relu')(hidden)

  # Output Layer
  output = keras.layers.Dense(units=num_classes, activation='softmax')(hidden)

  # Create model
  model = Model(model_input, output, name='small_model')

  return model

# %% [markdown]
# ### **Train**

# %%
############################
# Training Params
############################
learning_rate = 0.01
epochs = 15

# Free up memory
K.clear_session()

# Build the model
model = build_small_model(image_height, image_width, num_channels, num_classes)

# Print the model architecture
print(model.summary())

# Optimizer
optimizer = keras.optimizers.SGD(lr=learning_rate)

# Loss
loss = keras.losses.categorical_crossentropy

# Compile
model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Train model
start_time = time.time()
training_results = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs, 
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True)
# Out:
# Model: "small_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 401408)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                25690176
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 25,950,531
# Trainable params: 25,950,531
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/15
# 42/42 [==============================] - 18s 147ms/step - loss: 1.1081 - accuracy: 0.3360 - val_loss: 1.0949 - val_accuracy: 0.4054
# Epoch 2/15
# 42/42 [==============================] - 17s 143ms/step - loss: 1.0894 - accuracy: 0.4330 - val_loss: 1.0899 - val_accuracy: 0.4054
# Epoch 3/15
# 42/42 [==============================] - 17s 141ms/step - loss: 1.0796 - accuracy: 0.4211 - val_loss: 1.0910 - val_accuracy: 0.4054
# Epoch 4/15
# 42/42 [==============================] - 17s 141ms/step - loss: 1.0570 - accuracy: 0.4483 - val_loss: 1.0830 - val_accuracy: 0.3649
# Epoch 5/15
# 42/42 [==============================] - 17s 140ms/step - loss: 1.0516 - accuracy: 0.4505 - val_loss: 1.0964 - val_accuracy: 0.4257
# Epoch 6/15
# 42/42 [==============================] - 16s 140ms/step - loss: 1.0046 - accuracy: 0.5382 - val_loss: 1.0618 - val_accuracy: 0.4122
# Epoch 7/15
# 42/42 [==============================] - 16s 140ms/step - loss: 1.0004 - accuracy: 0.5140 - val_loss: 1.0444 - val_accuracy: 0.4595
# Epoch 8/15
# 42/42 [==============================] - 16s 141ms/step - loss: 0.9841 - accuracy: 0.5382 - val_loss: 1.0794 - val_accuracy: 0.4662
# Epoch 9/15
# 42/42 [==============================] - 17s 140ms/step - loss: 0.9762 - accuracy: 0.5243 - val_loss: 0.9956 - val_accuracy: 0.4797
# Epoch 10/15
# 42/42 [==============================] - 16s 140ms/step - loss: 0.9060 - accuracy: 0.5707 - val_loss: 0.9413 - val_accuracy: 0.5270
# Epoch 11/15
# 42/42 [==============================] - 16s 141ms/step - loss: 0.8935 - accuracy: 0.6056 - val_loss: 0.9331 - val_accuracy: 0.5541
# Epoch 12/15
# 42/42 [==============================] - 16s 141ms/step - loss: 0.8512 - accuracy: 0.6038 - val_loss: 0.9017 - val_accuracy: 0.6284
# Epoch 13/15
# 42/42 [==============================] - 16s 140ms/step - loss: 0.8692 - accuracy: 0.6023 - val_loss: 0.9150 - val_accuracy: 0.5270
# Epoch 14/15
# 42/42 [==============================] - 16s 140ms/step - loss: 0.7864 - accuracy: 0.6286 - val_loss: 0.9024 - val_accuracy: 0.5541
# Epoch 15/15
# 42/42 [==============================] - 16s 140ms/step - loss: 0.7372 - accuracy: 0.6545 - val_loss: 0.8337 - val_accuracy: 0.6284
# Training execution time (mins) 4.163591718673706
# 6/6 [==============================] - 2s 226ms/step - loss: 0.9186 - accuracy: 0.6061
# [0.9186182022094727, 0.6060606241226196]

# %% [markdown]
# ### **Medium CNN Network**

# %%
# Build Model
def build_medium_model(image_height, image_width, num_channels, num_classes):
  # Model input
  input_shape = [image_height, image_width, num_channels] # height, width, channels
  model_input = keras.Input(shape=input_shape)

  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(model_input)
  hidden = keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)

  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)
  
  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)
  
  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)

  # Flatten
  hidden = keras.layers.Flatten()(hidden)

  #  Hidden Layer, Classification Block
  hidden = keras.layers.Dense(units=64, activation='relu')(hidden)
  hidden = keras.layers.Dense(units=64, activation='relu')(hidden)

  # Output Layer
  output = keras.layers.Dense(units=num_classes, activation='softmax')(hidden)

  # Create model
  model = Model(model_input, output, name='medium_model')

  return model

# %% [markdown]
# ### **Train**

# %%
############################
# Training Params
############################
learning_rate = 0.01
epochs = 15

# Free up memory
K.clear_session()

# Build the model
model = build_medium_model(image_height, image_width, num_channels, num_classes)

# Print the model architecture
print(model.summary())

# Optimizer
optimizer = keras.optimizers.SGD(lr=learning_rate)

# Loss
loss = keras.losses.categorical_crossentropy

# Compile
model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Train model
start_time = time.time()
training_results = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs, 
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True)
# Out:
# Model: "medium_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                6422592
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 11,112,323
# Trainable params: 11,112,323
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/15
# 42/42 [==============================] - 24s 248ms/step - loss: 1.0988 - accuracy: 0.3333 - val_loss: 1.0983 - val_accuracy: 0.3446
# Epoch 2/15
# 42/42 [==============================] - 18s 189ms/step - loss: 1.0975 - accuracy: 0.3648 - val_loss: 1.0980 - val_accuracy: 0.3446
# Epoch 3/15
# 42/42 [==============================] - 19s 191ms/step - loss: 1.0969 - accuracy: 0.3846 - val_loss: 1.0973 - val_accuracy: 0.3514
# Epoch 4/15
# 42/42 [==============================] - 19s 194ms/step - loss: 1.0956 - accuracy: 0.4264 - val_loss: 1.0961 - val_accuracy: 0.4122
# Epoch 5/15
# 42/42 [==============================] - 19s 192ms/step - loss: 1.0936 - accuracy: 0.4280 - val_loss: 1.0948 - val_accuracy: 0.4122
# Epoch 6/15
# 42/42 [==============================] - 19s 190ms/step - loss: 1.0910 - accuracy: 0.4732 - val_loss: 1.0930 - val_accuracy: 0.4324
# Epoch 7/15
# 42/42 [==============================] - 18s 193ms/step - loss: 1.0859 - accuracy: 0.4627 - val_loss: 1.0905 - val_accuracy: 0.3716
# Epoch 8/15
# 42/42 [==============================] - 19s 193ms/step - loss: 1.0775 - accuracy: 0.4505 - val_loss: 1.0849 - val_accuracy: 0.4054
# Epoch 9/15
# 42/42 [==============================] - 19s 193ms/step - loss: 1.0604 - accuracy: 0.4807 - val_loss: 1.0834 - val_accuracy: 0.3986
# Epoch 10/15
# 42/42 [==============================] - 19s 193ms/step - loss: 1.0438 - accuracy: 0.4945 - val_loss: 1.0748 - val_accuracy: 0.4054
# Epoch 11/15
# 42/42 [==============================] - 19s 192ms/step - loss: 1.0396 - accuracy: 0.4954 - val_loss: 1.0959 - val_accuracy: 0.3649
# Epoch 12/15
# 42/42 [==============================] - 19s 192ms/step - loss: 1.0254 - accuracy: 0.4743 - val_loss: 1.1183 - val_accuracy: 0.3649
# Epoch 13/15
# 42/42 [==============================] - 19s 192ms/step - loss: 1.0298 - accuracy: 0.4893 - val_loss: 1.1545 - val_accuracy: 0.3649
# Epoch 14/15
# 42/42 [==============================] - 18s 191ms/step - loss: 1.0193 - accuracy: 0.5012 - val_loss: 1.0772 - val_accuracy: 0.3716
# Epoch 15/15
# 42/42 [==============================] - 19s 192ms/step - loss: 0.9791 - accuracy: 0.5162 - val_loss: 1.0332 - val_accuracy: 0.4527
# Training execution time (mins) 4.771090932687124
# 6/6 [==============================] - 2s 289ms/step - loss: 1.0291 - accuracy: 0.4545
# [1.0291485786437988, 0.4545454680919647]

# %% [markdown]
# ### **Large CNN Network**

# %%
# Build Model
def build_large_model(image_height, image_width, num_channels, num_classes):
  # Model input
  input_shape = [image_height, image_width, num_channels] # height, width, channels
  model_input = keras.Input(shape=input_shape)

  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(model_input)
  hidden = keras.layers.Conv2D(filters=64, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)

  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=128, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)
  
  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=256, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)
  
  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)
  
  # Hidden Layer, Convolution Block
  hidden = keras.layers.Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.Conv2D(filters=512, kernel_size=(3, 3), padding='same', activation='relu')(hidden)
  hidden = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(hidden)

  # Flatten
  hidden = keras.layers.Flatten()(hidden)

  #  Hidden Layer, Classification Block
  hidden = keras.layers.Dense(units=512, activation='relu')(hidden)
  hidden = keras.layers.Dense(units=512, activation='relu')(hidden)

  # Output Layer
  output = keras.layers.Dense(units=num_classes, activation='softmax')(hidden)

  # Create model
  model = Model(model_input, output, name='large_model')

  return model

# %% [markdown]
# ### **Train**

# %%
############################
# Training Params
############################
learning_rate = 0.01
epochs = 15

# Free up memory
K.clear_session()

# Build the model
model = build_large_model(image_height, image_width, num_channels, num_classes)

# Print the model architecture
print(model.summary())

# Optimizer
optimizer = keras.optimizers.SGD(lr=learning_rate)

# Loss
loss = keras.losses.categorical_crossentropy

# Compile
model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Train model
start_time = time.time()
training_results = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs, 
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True)
# Out:
# Model: "large_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 22,514,755
# Trainable params: 22,514,755
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/15
# 42/42 [==============================] - 21s 212ms/step - loss: 1.0981 - accuracy: 0.3452 - val_loss: 1.0984 - val_accuracy: 0.3514
# Epoch 2/15
# 42/42 [==============================] - 19s 201ms/step - loss: 1.0974 - accuracy: 0.3630 - val_loss: 1.0985 - val_accuracy: 0.2635
# Epoch 3/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0977 - accuracy: 0.3527 - val_loss: 1.0985 - val_accuracy: 0.3176
# Epoch 4/15
# 42/42 [==============================] - 19s 201ms/step - loss: 1.0960 - accuracy: 0.3727 - val_loss: 1.0981 - val_accuracy: 0.3311
# Epoch 5/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0959 - accuracy: 0.3557 - val_loss: 1.0983 - val_accuracy: 0.2838
# Epoch 6/15
# 42/42 [==============================] - 19s 201ms/step - loss: 1.0945 - accuracy: 0.3938 - val_loss: 1.0978 - val_accuracy: 0.2905
# Epoch 7/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0929 - accuracy: 0.3794 - val_loss: 1.0975 - val_accuracy: 0.3176
# Epoch 8/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0899 - accuracy: 0.4155 - val_loss: 1.0966 - val_accuracy: 0.3986
# Epoch 9/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0873 - accuracy: 0.4197 - val_loss: 1.0963 - val_accuracy: 0.3716
# Epoch 10/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0817 - accuracy: 0.4647 - val_loss: 1.0959 - val_accuracy: 0.3851
# Epoch 11/15
# 42/42 [==============================] - 19s 201ms/step - loss: 1.0792 - accuracy: 0.4618 - val_loss: 1.0990 - val_accuracy: 0.3649
# Epoch 12/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0722 - accuracy: 0.4708 - val_loss: 1.0974 - val_accuracy: 0.3919
# Epoch 13/15
# 42/42 [==============================] - 18s 200ms/step - loss: 1.0649 - accuracy: 0.4778 - val_loss: 1.1001 - val_accuracy: 0.3919
# Epoch 14/15
# 42/42 [==============================] - 18s 200ms/step - loss: 1.0682 - accuracy: 0.4375 - val_loss: 1.0929 - val_accuracy: 0.3649
# Epoch 15/15
# 42/42 [==============================] - 19s 200ms/step - loss: 1.0454 - accuracy: 0.4840 - val_loss: 1.1055 - val_accuracy: 0.3784
# Training execution time (mins) 4.707640834649404
# 6/6 [==============================] - 2s 232ms/step - loss: 1.0782 - accuracy: 0.4424
# [1.0781968832015991, 0.4424242377281189]

# %% [markdown]
# ### **MobileNet - Transfer Learning**

# %%
# Build Model
def build_mobilenet_model(image_height, image_width, num_channels, num_classes, train_base = False):

  # Model input
  input_shape = [image_height, image_width, num_channels] # height, width, channels

  # Load a pretrained model from keras.applications
  tranfer_model_base = keras.applications.MobileNetV2(input_shape=input_shape, weights='imagenet', include_top=False)

  # Freeze the mobileNet model layers
  tranfer_model_base.trainable = train_base

  # Regularize using L1
  kernel_weight = 0.02
  bias_weight = 0.02

  model = Sequential([
        tranfer_model_base,
        keras.layers.GlobalAveragePooling2D(),
        keras.layers.Dense(units=128, activation='relu',
                               kernel_regularizer=keras.regularizers.l1(kernel_weight), 
                               bias_regularizer=keras.regularizers.l1(bias_weight)),
        keras.layers.Dense(units=num_classes, activation='softmax',
                                  kernel_regularizer=keras.regularizers.l1(kernel_weight), 
                                  bias_regularizer=keras.regularizers.l1(bias_weight))
  ],name='mobilenetv2_train_base_'+str(train_base))

  return model

# %% [markdown]
# ### **Train - Freeze base**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 10

# Free up memory
K.clear_session()

# Build the model
model = build_mobilenet_model(image_height, image_width, num_channels, num_classes, train_base = False)

# Print the model architecture
print(model.summary())

# Optimizer
optimizer = keras.optimizers.SGD(lr=learning_rate)

# Loss
loss = keras.losses.categorical_crossentropy

# Compile
model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Train model
start_time = time.time()
training_results = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs, 
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9412608/9406464 [==============================] - 0s 0us/step
# Model: "mobilenetv2_train_base_False"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               163968
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,422,339
# Trainable params: 164,355
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None
# Epoch 1/10
# 42/42 [==============================] - 17s 87ms/step - loss: 108.2162 - accuracy: 0.4380 - val_loss: 105.9582 - val_accuracy: 0.5743
# Epoch 2/10
# 42/42 [==============================] - 13s 58ms/step - loss: 105.1962 - accuracy: 0.6106 - val_loss: 103.0834 - val_accuracy: 0.7027
# Epoch 3/10
# 42/42 [==============================] - 13s 66ms/step - loss: 102.3761 - accuracy: 0.6915 - val_loss: 100.3081 - val_accuracy: 0.7365
# Epoch 4/10
# 42/42 [==============================] - 14s 62ms/step - loss: 99.6235 - accuracy: 0.7456 - val_loss: 97.6044 - val_accuracy: 0.7635
# Epoch 5/10
# 42/42 [==============================] - 13s 61ms/step - loss: 96.9097 - accuracy: 0.8049 - val_loss: 94.9557 - val_accuracy: 0.7770
# Epoch 6/10
# 42/42 [==============================] - 14s 61ms/step - loss: 94.2614 - accuracy: 0.8529 - val_loss: 92.3563 - val_accuracy: 0.8108
# Epoch 7/10
# 42/42 [==============================] - 13s 59ms/step - loss: 91.7069 - accuracy: 0.8362 - val_loss: 89.8041 - val_accuracy: 0.8446
# Epoch 8/10
# 42/42 [==============================] - 13s 59ms/step - loss: 89.1665 - accuracy: 0.8312 - val_loss: 87.2926 - val_accuracy: 0.8649
# Epoch 9/10
# 42/42 [==============================] - 13s 59ms/step - loss: 86.6545 - accuracy: 0.8560 - val_loss: 84.8205 - val_accuracy: 0.8784
# Epoch 10/10
# 42/42 [==============================] - 13s 58ms/step - loss: 84.1751 - accuracy: 0.8726 - val_loss: 82.3872 - val_accuracy: 0.8851
# Training execution time (mins) 2.254645129044851
# 6/6 [==============================] - 2s 250ms/step - loss: 82.3901 - accuracy: 0.8606
# [82.39008331298828, 0.8606060743331909]

# %% [markdown]
# ### **Train - UnFreeze base (Finetuning)**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 10

# Free up memory
K.clear_session()

# Build the model
model = build_mobilenet_model(image_height, image_width, num_channels, num_classes, train_base = True)

# Print the model architecture
print(model.summary())

# Optimizer
optimizer = keras.optimizers.SGD(lr=learning_rate)

# Loss
loss = keras.losses.categorical_crossentropy

# Compile
model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Train model
start_time = time.time()
training_results = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs, 
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True)
# Out:
# Model: "mobilenetv2_train_base_True"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# mobilenetv2_1.00_224 (Functi (None, 7, 7, 1280)        2257984
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               163968
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,422,339
# Trainable params: 2,388,227
# Non-trainable params: 34,112
# _________________________________________________________________
# None
# Epoch 1/10
# 42/42 [==============================] - 23s 213ms/step - loss: 108.1351 - accuracy: 0.4148 - val_loss: 105.6917 - val_accuracy: 0.6689
# Epoch 2/10
# 42/42 [==============================] - 18s 186ms/step - loss: 104.9726 - accuracy: 0.7430 - val_loss: 102.8216 - val_accuracy: 0.7905
# Epoch 3/10
# 42/42 [==============================] - 18s 188ms/step - loss: 102.1156 - accuracy: 0.8208 - val_loss: 100.0596 - val_accuracy: 0.8243
# Epoch 4/10
# 42/42 [==============================] - 18s 185ms/step - loss: 99.3654 - accuracy: 0.8684 - val_loss: 97.3813 - val_accuracy: 0.8649
# Epoch 5/10
# 42/42 [==============================] - 18s 186ms/step - loss: 96.6741 - accuracy: 0.8968 - val_loss: 94.7480 - val_accuracy: 0.8784
# Epoch 6/10
# 42/42 [==============================] - 18s 188ms/step - loss: 94.0620 - accuracy: 0.8994 - val_loss: 92.1625 - val_accuracy: 0.8919
# Epoch 7/10
# 42/42 [==============================] - 18s 186ms/step - loss: 91.4552 - accuracy: 0.9250 - val_loss: 89.6192 - val_accuracy: 0.9054
# Epoch 8/10
# 42/42 [==============================] - 18s 190ms/step - loss: 88.9450 - accuracy: 0.9088 - val_loss: 87.1172 - val_accuracy: 0.9122
# Epoch 9/10
# 42/42 [==============================] - 18s 185ms/step - loss: 86.4333 - accuracy: 0.9276 - val_loss: 84.6527 - val_accuracy: 0.9054
# Epoch 10/10
# 42/42 [==============================] - 18s 182ms/step - loss: 83.9640 - accuracy: 0.9290 - val_loss: 82.2262 - val_accuracy: 0.9189
# Training execution time (mins) 3.0949591040611266
# 6/6 [==============================] - 2s 224ms/step - loss: 82.2454 - accuracy: 0.8545
# [82.24535369873047, 0.8545454740524292]

# %% [markdown]
# ### **MobileNet - Transfer Learning (From TFHub)**

# %%
# Build Model
def build_model_tfhub(image_height, image_width, num_channels, num_classes, train_base = False):

  # Model input
  input_shape = [image_height, image_width, num_channels] # height, width, channels

  # Handle to pretrained model
  handle = "https://tfhub.dev/google/imagenet/mobilenet_v2_100_224/feature_vector/4"

  # Regularize using L1
  kernel_weight = 0.02
  bias_weight = 0.02

  model = Sequential([
        keras.layers.InputLayer(input_shape=input_shape),
        hub.KerasLayer(handle, trainable=train_base),
        keras.layers.Dense(units=64, activation='relu',
                               kernel_regularizer=keras.regularizers.l1(kernel_weight), 
                               bias_regularizer=keras.regularizers.l1(bias_weight)),
        keras.layers.Dense(units=num_classes, activation='softmax',
                                  kernel_regularizer=keras.regularizers.l1(kernel_weight), 
                                  bias_regularizer=keras.regularizers.l1(bias_weight))
  ],name='tfhub_mobilenetv2_train_base_'+str(train_base))

  return model

# %% [markdown]
# ### **Train - Freeze base**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 10

# Free up memory
K.clear_session()

# Build the model
model = build_model_tfhub(image_height, image_width, num_channels, num_classes, train_base = False)

# Print the model architecture
print(model.summary())

# Optimizer
optimizer = keras.optimizers.SGD(lr=learning_rate)

# Loss
loss = keras.losses.categorical_crossentropy

# Compile
model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Train model
start_time = time.time()
training_results = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs, 
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True)
# Out:
# Model: "tfhub_mobilenetv2_train_base_False"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 64)                81984
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 2,340,163
# Trainable params: 82,179
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None
# Epoch 1/10
# 42/42 [==============================] - 17s 70ms/step - loss: 56.2018 - accuracy: 0.3140 - val_loss: 54.9784 - val_accuracy: 0.4932
# Epoch 2/10
# 42/42 [==============================] - 13s 55ms/step - loss: 54.6278 - accuracy: 0.5130 - val_loss: 53.4922 - val_accuracy: 0.6149
# Epoch 3/10
# 42/42 [==============================] - 12s 56ms/step - loss: 53.1381 - accuracy: 0.6688 - val_loss: 52.0605 - val_accuracy: 0.7027
# Epoch 4/10
# 42/42 [==============================] - 13s 56ms/step - loss: 51.7151 - accuracy: 0.7356 - val_loss: 50.6730 - val_accuracy: 0.7635
# Epoch 5/10
# 42/42 [==============================] - 13s 56ms/step - loss: 50.3492 - accuracy: 0.7705 - val_loss: 49.3204 - val_accuracy: 0.8176
# Epoch 6/10
# 42/42 [==============================] - 13s 55ms/step - loss: 48.9775 - accuracy: 0.8103 - val_loss: 47.9977 - val_accuracy: 0.8514
# Epoch 7/10
# 42/42 [==============================] - 13s 56ms/step - loss: 47.6703 - accuracy: 0.8170 - val_loss: 46.7002 - val_accuracy: 0.8514
# Epoch 8/10
# 42/42 [==============================] - 13s 56ms/step - loss: 46.3685 - accuracy: 0.8361 - val_loss: 45.4280 - val_accuracy: 0.8581
# Epoch 9/10
# 42/42 [==============================] - 13s 56ms/step - loss: 45.0862 - accuracy: 0.8600 - val_loss: 44.1796 - val_accuracy: 0.8581
# Epoch 10/10
# 42/42 [==============================] - 13s 55ms/step - loss: 43.8507 - accuracy: 0.8526 - val_loss: 42.9506 - val_accuracy: 0.8581
# Training execution time (mins) 2.1746229926745095
# 6/6 [==============================] - 2s 235ms/step - loss: 42.9440 - accuracy: 0.8424
# [42.944034576416016, 0.842424213886261]

# %% [markdown]
# ### **Train - UnFreeze base (Finetuning)**

# %%
############################
# Training Params
############################
learning_rate = 0.001
epochs = 10

# Free up memory
K.clear_session()

# Build the model
model = build_model_tfhub(image_height, image_width, num_channels, num_classes, train_base = True)

# Print the model architecture
print(model.summary())

# Optimizer
optimizer = keras.optimizers.SGD(lr=learning_rate)

# Loss
loss = keras.losses.categorical_crossentropy

# Compile
model.compile(loss=loss,
                  optimizer=optimizer,
                  metrics=['accuracy'])

# Train model
start_time = time.time()
training_results = model.fit(
        train_data,
        validation_data=validation_data,
        epochs=epochs, 
        verbose=1)
execution_time = (time.time() - start_time)/60.0
print("Training execution time (mins)",execution_time)

evaluate_save_model(model,test_data, training_results,execution_time, learning_rate, batch_size, epochs, optimizer,save=True)
# Out:
# Model: "tfhub_mobilenetv2_train_base_True"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 64)                81984
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 2,340,163
# Trainable params: 2,306,051
# Non-trainable params: 34,112
# _________________________________________________________________
# None
# Epoch 1/10
# 42/42 [==============================] - 25s 211ms/step - loss: 56.0982 - accuracy: 0.4868 - val_loss: 54.6713 - val_accuracy: 0.7838
# Epoch 2/10
# 42/42 [==============================] - 18s 193ms/step - loss: 54.3048 - accuracy: 0.7884 - val_loss: 53.1732 - val_accuracy: 0.8176
# Epoch 3/10
# 42/42 [==============================] - 18s 194ms/step - loss: 52.8236 - accuracy: 0.8542 - val_loss: 51.7736 - val_accuracy: 0.8514
# Epoch 4/10
# 42/42 [==============================] - 18s 194ms/step - loss: 51.4123 - accuracy: 0.8805 - val_loss: 50.4203 - val_accuracy: 0.8851
# Epoch 5/10
# 42/42 [==============================] - 18s 193ms/step - loss: 50.0451 - accuracy: 0.9024 - val_loss: 49.0993 - val_accuracy: 0.8919
# Epoch 6/10
# 42/42 [==============================] - 18s 194ms/step - loss: 48.7323 - accuracy: 0.9235 - val_loss: 47.8032 - val_accuracy: 0.9054
# Epoch 7/10
# 42/42 [==============================] - 18s 194ms/step - loss: 47.4183 - accuracy: 0.9290 - val_loss: 46.5282 - val_accuracy: 0.9122
# Epoch 8/10
# 42/42 [==============================] - 18s 194ms/step - loss: 46.1732 - accuracy: 0.9190 - val_loss: 45.2749 - val_accuracy: 0.9257
# Epoch 9/10
# 42/42 [==============================] - 18s 194ms/step - loss: 44.8782 - accuracy: 0.9462 - val_loss: 44.0405 - val_accuracy: 0.9257
# Epoch 10/10
# 42/42 [==============================] - 18s 193ms/step - loss: 43.6445 - accuracy: 0.9515 - val_loss: 42.8233 - val_accuracy: 0.9257
# Training execution time (mins) 3.1755759755770367
# 6/6 [==============================] - 2s 228ms/step - loss: 42.7994 - accuracy: 0.9091
# [42.7994499206543, 0.9090909361839294]

# %% [markdown]
# ## **Compare all Models**

# %%
models_store_path = "models"

models_metrics_list = glob(models_store_path+"/*_model_metrics.json")

all_models_metrics = []
for mm_file in models_metrics_list:
  with open(mm_file) as json_file:
    model_metrics = json.load(json_file)
    model_metrics["name"] = mm_file.replace("models/","").replace("_model_metrics.json","")
    all_models_metrics.append(model_metrics)

# Load metrics to dataframe
view_metrics = pd.DataFrame(data=all_models_metrics)

# Format columns
view_metrics['accuracy'] = view_metrics['accuracy']*100
view_metrics['accuracy'] = view_metrics['accuracy'].map('{:,.2f}%'.format)

view_metrics['trainable_parameters'] = view_metrics['trainable_parameters'].map('{:,.0f}'.format)
view_metrics['execution_time'] = view_metrics['execution_time'].map('{:,.2f} mins'.format)
view_metrics['loss'] = view_metrics['loss'].map('{:,.2f}'.format)
view_metrics['model_size'] = view_metrics['model_size']/1000000
view_metrics['model_size'] = view_metrics['model_size'].map('{:,.0f} MB'.format)

view_metrics = view_metrics.sort_values(by=['accuracy'],ascending=False)
view_metrics.head(10)
# Out:
#   trainable_parameters  ...                                name
# 0            2,306,051  ...   tfhub_mobilenetv2_train_base_True
# 1              164,355  ...        mobilenetv2_train_base_False
# 5            2,388,227  ...         mobilenetv2_train_base_True
# 3               82,179  ...  tfhub_mobilenetv2_train_base_False
# 2           25,950,531  ...                         small_model
# 6           11,112,323  ...                        medium_model
# 4           22,514,755  ...                         large_model
#
# [7 rows x 10 columns]

# %% [markdown]
# #### **Find Best Model**

# %%
best_model = 'models/'+view_metrics.iloc[0]["name"]+".hdf5"
print(best_model)
# Out:
# models/tfhub_mobilenetv2_train_base_True.hdf5

# %%
# To download the best model
# from google.colab import files
# files.download('models/'+view_metrics.iloc[0]["name"]+".hdf5")

# %% [markdown]
# ### **Predict using the best model**

# %%
# Load a model from disk
prediction_model = tf.keras.models.load_model(best_model, custom_objects={'KerasLayer':hub.KerasLayer})
#prediction_model = tf.keras.models.load_model(best_model)
prediction_model.summary()
# Out:
# Model: "tfhub_mobilenetv2_train_base_True"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 64)                81984
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 2,340,163
# Trainable params: 2,306,051
# Non-trainable params: 34,112
# _________________________________________________________________

# %%
# Generate a random sample of index
image_samples = np.random.randint(0,high=len(test_x)-1, size=12)
image_width = 224
image_height = 224
num_channels = 3

# Prepare the data
def preprocess_image(path):
  image = tf.io.read_file(path)
  image = tf.image.decode_jpeg(image, channels=num_channels)
  image = tf.image.resize(image, [image_height, image_width])

  image = keras.applications.mobilenet.preprocess_input(image)

  return image

prediction_image_paths = [test_x[img_idx] for img_idx in image_samples]
# Prepare the data for prediction
prediction_data = tf.data.Dataset.from_tensor_slices((prediction_image_paths))
prediction_data = prediction_data.map(preprocess_image, num_parallel_calls=AUTOTUNE)
prediction_data = prediction_data.batch(len(prediction_image_paths))

# Make prediction
predictions = prediction_model.predict(prediction_data)
print("predictions.shape:",predictions.shape)
print(predictions[0],predictions[0].argmax())

fig = plt.figure(figsize=(20,15))
for i,img_idx in enumerate(image_samples):
    axs = fig.add_subplot(4,3,i+1)
    
    # Read image
    image = cv2.imread(test_x[img_idx])
    # convert to rgb
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.imshow(image)

    # Actual label vs prediction
    prediction_label = index2label[predictions[i].argmax()]
    axs.set_title("Actual:"+test_y[img_idx]+", Pred:"+prediction_label)


    plt.axis('off')

plt.suptitle("Test predictions")
plt.show()
# Out:
# predictions.shape: (12, 3)
# [0.9342768  0.0251122  0.04061099] 0
